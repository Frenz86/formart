# %% [markdown]
# #Classi

# %%
class Persona:
    def __init__(self,a,b): # ATTRIBUTI
        self.nome = a
        self.eta = b

daniele = Persona('Daniele',36)
print(daniele)
print(daniele.nome)
# Out:
# <__main__.Persona object at 0x7fa0be1bbd00>
# Daniele

# %%
daniele.nome
# Out:
# 'Daniele'

# %%
class Persona:
    def __init__(self,a,b): # ATTRIBUTI
        self.nome = a
        self.eta = b

    def __str__(self):
        return f"Scheda Persona:\n  Nome:{self.nome}\n  età:{self.eta}"

daniele = Persona('Daniele',36)
print(daniele)
# Out:
# Scheda Persona:
#   Nome:Daniele
#   età:36

# %%
class Persona:
    def __init__(self,a,b): # ATTRIBUTI
        self.nome = a
        self.eta = b

    def __str__(self):
        return f"Scheda Persona:\n  Nome:{self.nome}\n  età:{self.eta}"

    def double(self,x): # METHOD
        ''' moltiplica l'input x2 volte'''
        return x*2

    def triple(self,x): # METHOD
        ''' moltiplica l'input x3 volte'''
        return x*3

    def quadratoanni(self): # METHOD
        ''' RESTITUISCE IL QUADRATO DEGLI ANNI'''
        return self.eta**2

daniele = Persona('Daniele',36)

# %%
bb = daniele.double(5)
bb
# Out:
# 10

# %%
daniele.double(23)
# Out:
# 46

# %%
marco= Persona('Marco',35)

# %%
marco.double(23)
# Out:
# 46

# %%
marco.quadratoanni()
# Out:
# 1225

# %%
####ciao
